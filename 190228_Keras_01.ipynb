# %% [markdown]
# ### 0. 사용할 패키지 불러오기

# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 1. 데이터셋 생성하기

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784).astype('float32')/255.0
x_test = x_test.reshape(10000, 784).astype('float32')/255.0
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %% [markdown]
# ### 2. 모델 구성하기

# %%
model = Sequential()
model.add(Dense(units=64, input_dim=28*28, activation='relu'))
model.add(Dense(units=10, activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### 3. 모델 학습과정 설정하기

# %%
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %% [markdown]
# ### 4. 모델 학습시키기

# %%
hist = model.fit(x_train, y_train, epochs=5, batch_size=32)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.6713 - acc: 0.8290
# Epoch 2/5
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.3525 - acc: 0.9006
# Epoch 3/5
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.3053 - acc: 0.9134
# Epoch 4/5
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.2763 - acc: 0.9214
# Epoch 5/5
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.2547 - acc: 0.9280

# %% [markdown]
# ### 5. 학습과정 살펴보기

# %%
print('## training loss and acc ##')
print(hist.history['loss'])
print(hist.history['acc'])
# Out:
# ## training loss and acc ##
# [0.6713179653326671, 0.35245923884312313, 0.3053127668639024, 0.2763230521341165, 0.25471243833800156]
# [0.8289666666666666, 0.90055, 0.9134, 0.9213833333333333, 0.9280333333333334]

# %%
### 6. 모델 평가하기
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=32)
print('## evaluation loss and metrics ##')
print(loss_and_metrics)
# Out:
# 10000/10000 [==============================] - 0s 32us/step
# ## evaluation loss and metrics ##
# [0.2436878135204315, 0.9307]

# %% [markdown]
# ### 7. 모델 사용하기

# %%
xhat = x_test[0:1]
yhat = model.predict(xhat)
print('## yhat ##')
print(yhat)
# Out:
# ## yhat ##
# [[1.3377976e-04 3.4106071e-07 2.2161914e-04 2.2027744e-03 8.7533854e-06
#   1.4677104e-04 4.3164864e-08 9.9676991e-01 4.7412690e-05 4.6858683e-04]]
